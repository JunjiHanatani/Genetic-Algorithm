# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import matplotlib
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['axes.titlesize'] = 18
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 14
matplotlib.rcParams['ytick.labelsize'] = 14
matplotlib.rcParams['legend.loc'] = 'best'
matplotlib.rcParams['legend.frameon'] = True
matplotlib.rcParams['legend.fontsize'] = 12
matplotlib.rcParams['legend.edgecolor'] = 'k'

# %%
sns.set(palette="Set2")
current_palette = sns.color_palette(n_colors=24)
sns.palplot(current_palette)

# %%
df_energy = pd.read_csv("./energy.csv")
df_energy.head(10)
# Out:
#     time  frame  Elastic Potential Energy  Gravitational Potential Energy  \
# 0  0.000      1                   2.10123                        0.470880
# 1  0.001      2                   2.08818                        0.470803
# 2  0.002      2                   2.06733                        0.470649
# 3  0.003      2                   2.03913                        0.470418
# 4  0.004      2                   2.00423                        0.470110
# 5  0.005      2                   1.96339                        0.469725
# 6  0.006      2                   1.91749                        0.469263
# 7  0.007      2                   1.86754                        0.468724
# 8  0.008      3                   1.81459                        0.468108
# 9  0.009      3                   1.75974                        0.467416
#
#    Contact Potential Energy  Kinetic Energy  External Energy  Total Energy
# 0                       0.0        0.004106                0       2.57622
# 1                       0.0        0.016225                0       2.57521
# 2                       0.0        0.035923                0       2.57390
# 3                       0.0        0.062602                0       2.57215
# 4                       0.0        0.095515                0       2.56986
# 5                       0.0        0.133791                0       2.56690
# 6                       0.0        0.176459                0       2.56321
# 7                       0.0        0.222472                0       2.55874
# 8                       0.0        0.270739                0       2.55344
# 9                       0.0        0.320149                0       2.54731

# %%
fig = plt.figure(figsize=[8, 6])
ax = fig.add_subplot(111)
df_energy.plot(ax=ax, 
               x="time", 
               y=["Elastic Potential Energy", 
                  "Gravitational Potential Energy", 
                  "Contact Potential Energy",
                  "Kinetic Energy",
                  "External Energy"], 
               kind='area', 
               stacked=True, 
               alpha=0.4,
               fontsize=14,
               title="Total Energy")

plt.show()

# %%
df_time = pd.read_csv("./time.csv")
df_time.plot(ylim=[1e-5, 1e-4])

df_time.describe()
# Out:
#        0.000603666
# count  2759.000000
# mean      0.000220
# std       0.001150
# min       0.000061
# 25%       0.000065
# 50%       0.000067
# 75%       0.000069
# max       0.022872

# %%
ref_vec = np.array([4, 2, 1])
norm = np.linalg.norm(ref_vec)
unit_vec = ref_vec/norm

vec1 = np.array([1, 2, 3])
vec2 = np.array([-2, 1, 4])
vec = vec2 - vec1
np.dot(unit_vec, vec)
# Out:
# -2.836832573067901

# %%
np.dot(unit_vec, vec1) - np.dot(unit_vec, vec2)
# Out:
# 2.836832573067901

# %%
unit_vec
# Out:
# array([0.87287156, 0.43643578, 0.21821789])

# %%
vec1
# Out:
# array([1, 2, 3])

# %%
np.dot(unit_vec, vec1)
# Out:
# 2.400396792595916
